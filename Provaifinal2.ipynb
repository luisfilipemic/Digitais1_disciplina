# %% [markdown]
# - Monitoramento em passos de 1 Litro;
#
# ---
#
# ### Circuito 2:(informações)
#
# Duas entradas (E e D) saidas = Y1Y0;
#
# - Caso1: reservatorio cheio DE = 00, saída = Y1Y0 = 10
#
# - Caso2: reservatorio parcialmente cheio DE= 10, saída = Y1Y0 = 00;
#
# - Caso3: reservatorio vazio DE = 11, saída  Y1Y0 = 01.
#
# ---
#
# Tabela verdade:
#
# | D | E | Y1 | Y0 |
# |---|---|----|----|
# | 0 | 0 |  1 |  0 |*
# | 0 | 1 |  x |  x |
# | 1 | 0 |  0 |  0 |*
# | 1 | 1 |  0 |  1 |*
#
#
# ---
#
# #### Analise de saídas: com base em soma de produtos;
#
#
# - y1:
#  Será alta quando DE = 00
#
#  logo y1 = 00;
#
#  y0:
#
#  Será alta quando DE = 11
#
#  logo Y0 = 11.
#
#  Ambas as expressões já estão na forma minima a ser representada.
#
#  circuito:
